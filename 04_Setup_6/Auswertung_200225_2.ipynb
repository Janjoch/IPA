# %%
# Stammdaten
rawdataFolder = "C:\\Users\\joerg_j\\switchdrive\\PSI\\22_e-Instrumentation\\HERO\\IPA\\Rohdaten"
campaignId    = "04_Setup_6"
measurementId = "200225_2"
signalAmplitude = 0.2

# %%
import sys
sys.path.append("../toolbox/")
from workflow import *
from jitterClass import analyseMeasurement
import importlib

# %%
M18_02 = analyseMeasurement(rawdataFolder, campaignId, measurementId, signalAmplitude, diagnose = True)

M18_02.read()

M18_02.showRawPulse(pulseNr = 0, style="o-")
# Out:
# read done
# showRawPulse done

# %%
M18_02.showRawPulse(pulseNr = 0, style="-")
# Out:
# showRawPulse done

# %%
absolute = False
threshold = 0.5

if(absolute):
    s = "Abs"
else:
    s = "Rel"
name = "thres{:d}".format(int(threshold * 100)) + s
 
M18_02.threshold(absolute = absolute, threshold = threshold)

M18_02.calculateDelta(name + "F", M18_02.data["thres"][name][0,0,:,0], M18_02.data["thres"][name][1,0,:,0])
M18_02.calculateDelta(name + "C", M18_02.data["thres"][name][0,1,:,0], M18_02.data["thres"][name][1,1,:,0])
M18_02.calculateDelta(name + "R", M18_02.data["thres"][name][0,2,:,0], M18_02.data["thres"][name][1,2,:,0])

M18_02.histogram(name + "F", name + "F")
M18_02.histogram(name + "C", name + "C")
M18_02.histogram(name + "R", name + "R")

M18_02.fitHist(name + "F", name + "F")
M18_02.fitHist(name + "C", name + "C")
M18_02.fitHist(name + "R", name + "R")
# Out:
# xt: 7.54094085710336e-09 ps, yt -0.04999598218637402 ps
# xt: 7.862953297545038e-09 ps, yt -0.04999598218637402 ps
# xt: 7.135157019860023e-09 ps, yt -0.04255661652132403 ps
# xt: 7.488836334059285e-09 ps, yt -0.04255661652132403 ps
# calculateDelta done
# calculateDelta done
# calculateDelta done
# histogram done
# histogram done
# histogram done
# 50
# parameter: [1.43472557e-09 3.99402268e-10 3.11411023e-12] [A, mu, sigma]
# fitHist done
# 52
# parameter: [1.30209626e-09 3.85001530e-10 2.99048084e-12] [A, mu, sigma]
# fitHist done
# 49
# parameter: [2.73089343e-09 3.70560899e-10 6.26628654e-12] [A, mu, sigma]
# fitHist done

# %%
M18_02.showResult(name + "F")
print("---------------------------------------------------------------------------------------")
M18_02.showResult(name + "C")
print("---------------------------------------------------------------------------------------")
M18_02.showResult(name + "R")
# Out:
# σ_0: 3.114110234027686 ps
# σ_1: 2.202008463843403 ps
# σ_1 = σ_0 / sqrt(2)
#
# μ: 399.402267872724 ps
#
# coma separated [σ_0, σ_1, μ]
# 3.1141102340276857e-12,2.202008463843403e-12,3.99402267872724e-10
#
#  tab separated [σ_0, σ_1, μ]
# 3.1141102340276857e-12	2.202008463843403e-12	3.99402267872724e-10
# ---------------------------------------------------------------------------------------
# σ_0: 2.9904808401471357 ps
# σ_1: 2.114589281076483 ps
# σ_1 = σ_0 / sqrt(2)
#
# μ: 385.0015295522661 ps
#
# coma separated [σ_0, σ_1, μ]
# 2.9904808401471356e-12,2.114589281076483e-12,3.850015295522661e-10
#
#  tab separated [σ_0, σ_1, μ]
# 2.9904808401471356e-12	2.114589281076483e-12	3.850015295522661e-10
# ---------------------------------------------------------------------------------------
# σ_0: 6.26628654283038 ps
# σ_1: 4.430933707293368 ps
# σ_1 = σ_0 / sqrt(2)
#
# μ: 370.5608993803079 ps
#
# coma separated [σ_0, σ_1, μ]
# 6.26628654283038e-12,4.430933707293368e-12,3.705608993803079e-10
#
#  tab separated [σ_0, σ_1, μ]
# 6.26628654283038e-12	4.430933707293368e-12	3.705608993803079e-10

# %%
M18_02.fitGauss(threshold = 0.2, diagnosePulse=0)

M18_02.calculateDelta("gauss", M18_02.data["gauss"][0,:,1], M18_02.data["gauss"][1,:,1])

M18_02.histogram("gauss", "gauss")

M18_02.fitHist("gauss", "gauss")
# Out:
# iPeak: 38 iLeft: 30 iRight: 51
# parameter: [-3.43898936e-11  7.69954695e-09  1.40846709e-10] [A, mu, sigma]
# iPeak: 23 iLeft: 14 iRight: 36
# parameter: [-3.19483095e-11  7.30909267e-09  1.51924877e-10] [A, mu, sigma]
# fitGauss done
# calculateDelta done
# histogram done
# 46
# parameter: [7.59517593e-10 3.87727992e-10 1.68919748e-12] [A, mu, sigma]
# fitHist done

# %%
M18_02.fitGauss(threshold = 0.2, diagnosePulse=0)

M18_02.calculateDelta("gaussO", M18_02.data["gauss"][0,:,1][2:], M18_02.data["gauss"][1,:,1][:-2])

M18_02.histogram("gaussO", "gaussO")

M18_02.fitHist("gaussO", "gaussO")
# Out:
# iPeak: 40 iLeft: 31 iRight: 53
# parameter: [-1.14825174e-10  7.73573869e-09  1.53060507e-10] [A, mu, sigma]
# iPeak: 23 iLeft: 15 iRight: 37
# parameter: [-1.07973197e-10  7.31700067e-09  1.55010669e-10] [A, mu, sigma]
# fitGauss done
# calculateDelta done
# histogram done
# 54
# parameter: [1.31535231e-09 4.18327387e-10 3.37909257e-12] [A, mu, sigma]
# fitHist done

# %%
M18_02.showResult("gauss")
# Out:
# σ_0: 1.6891974783597272 ps
# σ_1: 1.1944429917113795 ps
# σ_1 = σ_0 / sqrt(2)
#
# μ: 387.7279921091111 ps
#
# coma separated [σ_0, σ_1, μ]
# 1.6891974783597272e-12,1.1944429917113795e-12,3.877279921091111e-10
#
#  tab separated [σ_0, σ_1, μ]
# 1.6891974783597272e-12	1.1944429917113795e-12	3.877279921091111e-10

# %%
M18_02.showResult("gaussO")
# Out:
# σ_0: 3.379092573131937 ps
# σ_1: 2.3893792727186924 ps
# σ_1 = σ_0 / sqrt(2)
#
# μ: 418.32738732917693 ps
#
# coma separated [σ_0, σ_1, μ]
# 3.379092573131937e-12,2.3893792727186925e-12,4.1832738732917695e-10
#
#  tab separated [σ_0, σ_1, μ]
# 3.379092573131937e-12	2.3893792727186925e-12	4.1832738732917695e-10

# %%
plt.plot(M18_02.data["gauss"][0,:,1][:20])
plt.plot(M18_02.data["gauss"][1,:,1][0:20] + 0.39e-9)

# %%
plt.plot(M18_02.data["gauss"][0,:,1] - M18_02.data["gauss"][1,:,1])

# %%
# %load_ext autoreload

# %%
exportedDict = M18_02.exportDict()
# %autoreload
M18_02 = analyseMeasurement(diagnose = True)
M18_02.importDict(exportedDict)
# Out:
# exportDict done
# importDict done
