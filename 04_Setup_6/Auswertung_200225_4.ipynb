# %%
# Stammdaten
rawdataFolder = "C:\\Users\\joerg_j\\switchdrive\\PSI\\22_e-Instrumentation\\HERO\\IPA\\Rohdaten"
campaignId    = "04_Setup_6"
measurementId = "200225_4"
signalAmplitude = 0.2

# %%
import sys
sys.path.append("../toolbox/")
from workflow import *
from jitterClass import analyseMeasurement
import importlib

# %%
M18_02 = analyseMeasurement(rawdataFolder, campaignId, measurementId, signalAmplitude, diagnose = True)

M18_02.read()

M18_02.showRawPulse(pulseNr = 0, style="o-")
# Out:
# read done
# showRawPulse done

# %%
M18_02.diagnose(True, True, True, figsize=(8,4))

# %%
M18_02.showRawPulse(pulseNr = 0, style="-")
# Out:
# showRawPulse done

# %%
absolute = False
threshold = 0.5

if(absolute):
    s = "Abs"
else:
    s = "Rel"
name = "thres{:d}".format(int(threshold * 100)) + s
 
M18_02.threshold(absolute = absolute, threshold = threshold)

M18_02.calculateDelta(name + "F", M18_02.data["thres"][name][0,0,:,0], M18_02.data["thres"][name][1,0,:,0])
M18_02.calculateDelta(name + "C", M18_02.data["thres"][name][0,1,:,0], M18_02.data["thres"][name][1,1,:,0])
M18_02.calculateDelta(name + "R", M18_02.data["thres"][name][0,2,:,0], M18_02.data["thres"][name][1,2,:,0])

M18_02.histogram(name + "F", name + "F")
M18_02.histogram(name + "C", name + "C")
M18_02.histogram(name + "R", name + "R")

M18_02.fitHist(name + "F", name + "F")
M18_02.fitHist(name + "C", name + "C")
M18_02.fitHist(name + "R", name + "R")
# Out:
# xt: 7.551611323024879e-09 ps, yt -0.005872065898188339 ps
# xt: 7.795987037821518e-09 ps, yt -0.005872065898188339 ps
# xt: 7.102509632977174e-09 ps, yt -0.003105457118635968 ps
# xt: 7.504064018439854e-09 ps, yt -0.003105457118635968 ps
# calculateDelta done
# calculateDelta done
# calculateDelta done
# histogram done
# histogram done
# histogram done
# 44
# parameter: [9.65278618e-09 4.00975394e-10 2.62710976e-11] [A, mu, sigma]
# fitHist done
# 56
# parameter: [8.32092403e-09 3.82162337e-10 2.33065740e-11] [A, mu, sigma]
# fitHist done
# 54
# parameter: [1.70473441e-08 3.62910208e-10 5.28406999e-11] [A, mu, sigma]
# fitHist done

# %%
M18_02.showResult(name + "F")
print("---------------------------------------------------------------------------------------")
M18_02.showResult(name + "C")
print("---------------------------------------------------------------------------------------")
M18_02.showResult(name + "R")
# Out:
# σ_0: 26.271097592502727 ps
# σ_1: 18.57647125687226 ps
# σ_1 = σ_0 / sqrt(2)
#
# μ: 400.97539363780555 ps
#
# coma separated [σ_0, σ_1, μ]
# 2.6271097592502726e-11,1.857647125687226e-11,4.0097539363780554e-10
#
#  tab separated [σ_0, σ_1, μ]
# 2.6271097592502726e-11	1.857647125687226e-11	4.0097539363780554e-10
# ---------------------------------------------------------------------------------------
# σ_0: 23.306573964346722 ps
# σ_1: 16.4802364964154 ps
# σ_1 = σ_0 / sqrt(2)
#
# μ: 382.1623367628781 ps
#
# coma separated [σ_0, σ_1, μ]
# 2.330657396434672e-11,1.64802364964154e-11,3.8216233676287813e-10
#
#  tab separated [σ_0, σ_1, μ]
# 2.330657396434672e-11	1.64802364964154e-11	3.8216233676287813e-10
# ---------------------------------------------------------------------------------------
# σ_0: 52.84069986772284 ps
# σ_1: 37.364017199109924 ps
# σ_1 = σ_0 / sqrt(2)
#
# μ: 362.91020801504266 ps
#
# coma separated [σ_0, σ_1, μ]
# 5.284069986772284e-11,3.736401719910992e-11,3.6291020801504265e-10
#
#  tab separated [σ_0, σ_1, μ]
# 5.284069986772284e-11	3.736401719910992e-11	3.6291020801504265e-10

# %%
M18_02.fitGauss(threshold = 0.2, diagnosePulse=0)

M18_02.calculateDelta("gauss", M18_02.data["gauss"][0,:,1], M18_02.data["gauss"][1,:,1])

M18_02.histogram("gauss", "gauss")

M18_02.fitHist("gauss", "gauss")
# Out:
# iPeak: 38 iLeft: 31 iRight: 51
# parameter: [-3.52198386e-12  7.68503491e-09  1.32862435e-10] [A, mu, sigma]
# iPeak: 20 iLeft: 14 iRight: 35
# parameter: [-2.66314141e-12  7.29510969e-09  1.66922670e-10] [A, mu, sigma]
# fitGauss done
# calculateDelta done
# histogram done
# 50
# parameter: [5.73352695e-09 3.82964492e-10 1.54662457e-11] [A, mu, sigma]
# fitHist done

# %%
M18_02.showResult("gauss")
# Out:
# σ_0: 15.466245682865962 ps
# σ_1: 10.936287201851686 ps
# σ_1 = σ_0 / sqrt(2)
#
# μ: 382.9644919079117 ps
#
# coma separated [σ_0, σ_1, μ]
# 1.5466245682865962e-11,1.0936287201851686e-11,3.8296449190791166e-10
#
#  tab separated [σ_0, σ_1, μ]
# 1.5466245682865962e-11	1.0936287201851686e-11	3.8296449190791166e-10

# %%
plt.plot(M18_02.data["gauss"][0,:,1][:20])
plt.plot(M18_02.data["gauss"][1,:,1][0:20] + 0.39e-9)

# %%
plt.plot(M18_02.data["gauss"][0,:,1] - M18_02.data["gauss"][1,:,1])

# %%
# %load_ext autoreload

# %%
exportedDict = M18_02.exportDict()
# %autoreload
M18_02 = analyseMeasurement(diagnose = True)
M18_02.importDict(exportedDict)
