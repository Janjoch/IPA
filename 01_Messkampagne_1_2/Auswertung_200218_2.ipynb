# %%
# Stammdaten
rawdataFolder = "C:\\Users\\joerg_j\\switchdrive\\PSI\\22_e-Instrumentation\\HERO\\IPA\\Rohdaten"
campaignId    = "01_Messkampagne_1"
measurementId = "200218_2"

# %%
import sys
sys.path.append("../toolbox/")
from workflow import *
from jitterClass import analyseMeasurement
import importlib

# %%
# %load_ext autoreload

# %%
exportedDict = M18_02.exportDict()
# %autoreload
#importlib.reload(analyseMeasurement)
M18_02 = analyseMeasurement()
M18_02.importDict(exportedDict)

# %%
M18_02 = analyseMeasurement(rawdataFolder, campaignId, measurementId)

# %%
M18_02.read()

# %%
M18_02.showRawPulse(pulseNr = 0,channelNrs = [0,1], areaMax = 50, style="o-")

# %%
M18_02.fitGauss(threshold = 0.2, diagnosePulse=13)

# %%
plt.plot(M18_02.data["gauss"][0,:,1])

# %%
M18_02.calculateDelta("gauss", M18_02.data["gauss"][0,:,1], M18_02.data["gauss"][1,:,1])

# %%
M18_02.histogram("gauss", "gauss")

# %%
M18_02.fitHist("gauss", "gauss")
# Out:
# 50
# parameter: [3.81329390e-10 1.04720977e-10 9.56867988e-13] [A, mu, sigma]

# %%
M18_02.data["result"]["gauss"][2] * 1e12
# Out:
# 0.9568679875024821
