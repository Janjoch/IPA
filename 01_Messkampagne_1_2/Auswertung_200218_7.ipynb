# %%
# Stammdaten
rawdataFolder = "C:\\Users\\joerg_j\\switchdrive\\PSI\\22_e-Instrumentation\\HERO\\IPA\\Rohdaten"
campaignId    = "01_Messkampagne_1"
measurementId = "200218_7"
signalAmplitude = 0.2

# %%
import sys
sys.path.append("../toolbox/")
from workflow import *
from jitterClass import analyseMeasurement
import importlib

# %%
M18_02 = analyseMeasurement(rawdataFolder, campaignId, measurementId, signalAmplitude, diagnose = True)

M18_02.read()

M18_02.showRawPulse(pulseNr = 0, style="o-")
# Out:
# read done
# showRawPulse done

# %%
M18_02.showRawPulse(pulseNr = 0, style="-")
# Out:
# showRawPulse done

# %%
absolute = False
threshold = 0.3

if(absolute):
    s = "Abs"
else:
    s = "Rel"
name = "thres{:d}".format(int(threshold * 100)) + s
 
M18_02.threshold(absolute = absolute, threshold = threshold)

M18_02.calculateDelta(name + "F", M18_02.data["thres"][name][0,0,:,0], M18_02.data["thres"][name][1,0,:,0])
M18_02.calculateDelta(name + "C", M18_02.data["thres"][name][0,1,:,0], M18_02.data["thres"][name][1,1,:,0])
M18_02.calculateDelta(name + "R", M18_02.data["thres"][name][0,2,:,0], M18_02.data["thres"][name][1,2,:,0])

M18_02.histogram(name + "F", name + "F")
M18_02.histogram(name + "C", name + "C")
M18_02.histogram(name + "R", name + "R")

M18_02.fitHist(name + "F", name + "F")
M18_02.fitHist(name + "C", name + "C")
M18_02.fitHist(name + "R", name + "R")
# Out:
# xt: 1.0681667496303099e-08 ps, yt -0.003033334433962409 ps
# xt: 1.0860681430050825e-08 ps, yt -0.003033334433962409 ps
# xt: 1.0584324344142366e-08 ps, yt -0.00220044140853588 ps
# xt: 1.0766979880775523e-08 ps, yt -0.00220044140853588 ps
# calculateDelta done
# calculateDelta done
# calculateDelta done
# histogram done
# histogram done
# histogram done
# 55
# parameter: [5.57973700e-09 9.93933616e-11 1.42591924e-11] [A, mu, sigma]
# fitHist done
# 50
# parameter: [3.29800665e-09 1.00070129e-10 7.30089068e-12] [A, mu, sigma]
# fitHist done
# 50
# parameter: [3.88318655e-09 1.00447889e-10 1.06652809e-11] [A, mu, sigma]
# fitHist done

# %%
M18_02.showResult(name + "F")
print("---------------------------------------------------------------------------------------")
M18_02.showResult(name + "C")
print("---------------------------------------------------------------------------------------")
M18_02.showResult(name + "R")
# Out:
# σ_0: 14.259192441808677 ps
# σ_1: 10.08277166984688 ps
# σ_1 = σ_0 / sqrt(2)
#
# μ: 99.39336157054115 ps
#
# coma separated [σ_0, σ_1, μ]
# 1.4259192441808678e-11,1.008277166984688e-11,9.939336157054115e-11
#
#  tab separated [σ_0, σ_1, μ]
# 1.4259192441808678e-11	1.008277166984688e-11	9.939336157054115e-11
# ---------------------------------------------------------------------------------------
# σ_0: 7.3008906772310525 ps
# σ_1: 5.162509306571722 ps
# σ_1 = σ_0 / sqrt(2)
#
# μ: 100.0701288250771 ps
#
# coma separated [σ_0, σ_1, μ]
# 7.300890677231053e-12,5.162509306571722e-12,1.0007012882507711e-10
#
#  tab separated [σ_0, σ_1, μ]
# 7.300890677231053e-12	5.162509306571722e-12	1.0007012882507711e-10
# ---------------------------------------------------------------------------------------
# σ_0: 10.665280903757655 ps
# σ_1: 7.541492450306426 ps
# σ_1 = σ_0 / sqrt(2)
#
# μ: 100.44788901250622 ps
#
# coma separated [σ_0, σ_1, μ]
# 1.0665280903757654e-11,7.541492450306426e-12,1.0044788901250622e-10
#
#  tab separated [σ_0, σ_1, μ]
# 1.0665280903757654e-11	7.541492450306426e-12	1.0044788901250622e-10

# %%
M18_02.fitGauss(threshold = 0.2, diagnosePulse=0)

M18_02.calculateDelta("gauss", M18_02.data["gauss"][0,:,1], M18_02.data["gauss"][1,:,1])

M18_02.histogram("gauss", "gauss")

M18_02.fitHist("gauss", "gauss")
# Out:
# iPeak: 32 iLeft: 27 iRight: 36
# parameter: [-1.47716427e-12  1.07689829e-08  5.62810917e-11] [A, mu, sigma]
# iPeak: 28 iLeft: 24 iRight: 33
# parameter: [-1.10232039e-12  1.06729525e-08  5.85975471e-11] [A, mu, sigma]
# fitGauss done
# calculateDelta done
# histogram done
# 52
# parameter: [2.80024160e-09 1.00883331e-10 7.27199313e-12] [A, mu, sigma]
# fitHist done

# %%
M18_02.showResult("gauss")
# Out:
# σ_0: 7.271993127690616 ps
# σ_1: 5.142075653332006 ps
# σ_1 = σ_0 / sqrt(2)
#
# μ: 100.8833312416228 ps
#
# coma separated [σ_0, σ_1, μ]
# 7.2719931276906156e-12,5.142075653332005e-12,1.008833312416228e-10
#
#  tab separated [σ_0, σ_1, μ]
# 7.2719931276906156e-12	5.142075653332005e-12	1.008833312416228e-10

# %%
# %load_ext autoreload

# %%
exportedDict = M18_02.exportDict()
# %autoreload
M18_02 = analyseMeasurement(diagnose = True)
M18_02.importDict(exportedDict)
# Out:
# exportDict done
# importDict done
