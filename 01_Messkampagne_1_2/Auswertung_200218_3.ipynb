# %%
# Stammdaten
rawdataFolder = "C:\\Users\\joerg_j\\switchdrive\\PSI\\22_e-Instrumentation\\HERO\\IPA\\Rohdaten"
campaignId    = "01_Messkampagne_1"
measurementId = "200218_3"
signalAmplitude = 0.2

# %%
import sys
sys.path.append("../toolbox/")
from workflow import *
from jitterClass import analyseMeasurement
import importlib

# %%
M18_02 = analyseMeasurement(rawdataFolder, campaignId, measurementId, signalAmplitude, diagnose = True)

M18_02.read()

M18_02.showRawPulse(pulseNr = 0, style="o-")
# Out:
# read done
# showRawPulse done

# %%
M18_02.data["raw"][0,0,0]
# Out:
# array([9.97491972e-09, 9.99991972e-09, 1.00249197e-08, 1.00499197e-08,
#        1.00749197e-08, 1.00999197e-08, 1.01249197e-08, 1.01499197e-08,
#        1.01749197e-08, 1.01999197e-08, 1.02249197e-08, 1.02499197e-08,
#        1.02749197e-08, 1.02999197e-08, 1.03249197e-08, 1.03499197e-08,
#        1.03749197e-08, 1.03999197e-08, 1.04249197e-08, 1.04499197e-08,
#        1.04749197e-08, 1.04999197e-08, 1.05249197e-08, 1.05499197e-08,
#        1.05749197e-08, 1.05999197e-08, 1.06249197e-08, 1.06499197e-08,
#        1.06749197e-08, 1.06999197e-08, 1.07249197e-08, 1.07499197e-08,
#        1.07749197e-08, 1.07999197e-08, 1.08249197e-08, 1.08499197e-08,
#        1.08749197e-08, 1.08999197e-08, 1.09249197e-08, 1.09499197e-08,
#        1.09749197e-08, 1.09999197e-08, 1.10249197e-08, 1.10499197e-08,
#        1.10749197e-08, 1.10999197e-08, 1.11249197e-08, 1.11499197e-08,
#        1.11749197e-08, 1.11999197e-08, 1.12249197e-08, 1.12499197e-08,
#        1.12749197e-08, 1.12999197e-08, 1.13249197e-08, 1.13499197e-08,
#        1.13749197e-08, 1.13999197e-08, 1.14249197e-08, 1.14499197e-08,
#        1.14749197e-08, 1.14999197e-08, 1.15249197e-08, 1.15499197e-08,
#        1.15749197e-08, 1.15999197e-08, 1.16249197e-08, 1.16499197e-08,
#        1.16749197e-08, 1.16999197e-08, 1.17249197e-08, 1.17499197e-08,
#        1.17749197e-08, 1.17999197e-08, 1.18249197e-08, 1.18499197e-08,
#        1.18749197e-08, 1.18999197e-08, 1.19249197e-08, 1.19499197e-08,
#        1.19749197e-08, 1.19999197e-08])

# %%
M18_02.showRawPulse(pulseNr = 0, style="-")
# Out:
# showRawPulse done

# %%
absolute = True
threshold = 0.3

if(absolute):
    s = "Abs"
else:
    s = "Rel"
name = "thres{:d}".format(int(threshold * 100)) + s
 
M18_02.threshold(absolute = absolute, threshold = threshold)

M18_02.calculateDelta(name + "F", M18_02.data["thres"][name][0,0,:,0], M18_02.data["thres"][name][1,0,:,0])
M18_02.calculateDelta(name + "C", M18_02.data["thres"][name][0,1,:,0], M18_02.data["thres"][name][1,1,:,0])
M18_02.calculateDelta(name + "R", M18_02.data["thres"][name][0,2,:,0], M18_02.data["thres"][name][1,2,:,0])

M18_02.histogram(name + "F", name + "F")
M18_02.histogram(name + "C", name + "C")
M18_02.histogram(name + "R", name + "R")

M18_02.fitHist(name + "F", name + "F")
M18_02.fitHist(name + "C", name + "C")
M18_02.fitHist(name + "R", name + "R")
# Out:
# xt: 1.0678215532895071e-08 ps, yt -0.06 ps
# xt: 1.0876910769019295e-08 ps, yt -0.06 ps
# xt: 1.0591350853125623e-08 ps, yt -0.06 ps
# xt: 1.0753176407208343e-08 ps, yt -0.06 ps
# calculateDelta done
# calculateDelta done
# calculateDelta done
# histogram done
# histogram done
# histogram done
# 53
# parameter: [9.71689031e-10 8.64207034e-11 2.10258854e-12] [A, mu, sigma]
# fitHist done
# 48
# parameter: [5.15736627e-10 1.05152552e-10 1.29776318e-12] [A, mu, sigma]
# fitHist done
# 47
# parameter: [9.01658110e-10 1.23880498e-10 1.84379074e-12] [A, mu, sigma]
# fitHist done

# %%
M18_02.showResult(name + "F")
print("---------------------------------------------------------------------------------------")
M18_02.showResult(name + "C")
print("---------------------------------------------------------------------------------------")
M18_02.showResult(name + "R")
# Out:
# σ_0: 2.1025885377438205 ps
# σ_1: 1.4867546130837626 ps
# σ_1 = σ_0 / sqrt(2)
#
# μ: 86.4207033761276 ps
#
# coma separated [σ_0, σ_1, μ]
# 2.1025885377438206e-12,1.4867546130837625e-12,8.64207033761276e-11
#
#  tab separated [σ_0, σ_1, μ]
# 2.1025885377438206e-12	1.4867546130837625e-12	8.64207033761276e-11
# ---------------------------------------------------------------------------------------
# σ_0: 1.2977631797295586 ps
# σ_1: 0.9176571447609871 ps
# σ_1 = σ_0 / sqrt(2)
#
# μ: 105.1525518204079 ps
#
# coma separated [σ_0, σ_1, μ]
# 1.2977631797295586e-12,9.17657144760987e-13,1.0515255182040789e-10
#
#  tab separated [σ_0, σ_1, μ]
# 1.2977631797295586e-12	9.17657144760987e-13	1.0515255182040789e-10
# ---------------------------------------------------------------------------------------
# σ_0: 1.8437907416916681 ps
# σ_1: 1.3037569365391524 ps
# σ_1 = σ_0 / sqrt(2)
#
# μ: 123.88049788725935 ps
#
# coma separated [σ_0, σ_1, μ]
# 1.843790741691668e-12,1.3037569365391523e-12,1.2388049788725935e-10
#
#  tab separated [σ_0, σ_1, μ]
# 1.843790741691668e-12	1.3037569365391523e-12	1.2388049788725935e-10

# %%
M18_02.fitGauss(threshold = 0.2, diagnosePulse=0)

M18_02.calculateDelta("gauss", M18_02.data["gauss"][0,:,1], M18_02.data["gauss"][1,:,1])

M18_02.histogram("gauss", "gauss")

M18_02.fitHist("gauss", "gauss")
# Out:
# iPeak: 32 iLeft: 27 iRight: 37
# parameter: [-3.27111587e-11  1.07790661e-08  6.49645962e-11] [A, mu, sigma]
# iPeak: 28 iLeft: 23 iRight: 33
# parameter: [-2.10359595e-11  1.06728171e-08  6.27800384e-11] [A, mu, sigma]
# fitGauss done
# calculateDelta done
# histogram done
# 49
# parameter: [5.74613746e-10 1.07170386e-10 1.37856422e-12] [A, mu, sigma]
# fitHist done

# %%
M18_02.showResult("gauss")
# Out:
# σ_0: 1.3785642226256112 ps
# σ_1: 0.974792110119731 ps
# σ_1 = σ_0 / sqrt(2)
#
# μ: 107.17038561014597 ps
#
# coma separated [σ_0, σ_1, μ]
# 1.3785642226256111e-12,9.74792110119731e-13,1.0717038561014597e-10
#
#  tab separated [σ_0, σ_1, μ]
# 1.3785642226256111e-12	9.74792110119731e-13	1.0717038561014597e-10

# %%
# %load_ext autoreload

# %%
exportedDict = M18_02.exportDict()
# %autoreload
M18_02 = analyseMeasurement(diagnose = True)
M18_02.importDict(exportedDict)
# Out:
# exportDict done
# importDict done
